# %%
# CEO list of all companies in Project 1. TWTR Handle = Personal Twitter Account Username.
CEOs = [
    {
        "CEO_Name": "Elon Musk",
        "Company": "Tesla",
        "Company_Ticker": "TSLA",
        "Age": 50,
        "TWTR_Handle": "elonmusk", 
    },
    {
        "CEO_Name": "Jim Farley",
        "Company": "Ford Motor Company",
        "Company_Ticker": "F",
        "Age": 58,
        "TWTR_Handle": "jimfarley98",
    },
    { 
        "CEO_Name": "Jim Hackett",
        "Company": "Ford Motor Company",
        "Company_Ticker": "F",
        "Age": 66,
        "TWTR_Handle": "null",  
    },  
    { 
        "CEO_Name": "Mary Barra",
        "Company": "General Motors",
        "Company_Ticker": "GM",
        "Age": 59,
        "TWTR_Handle": "mtbarra",
    },
    {
        "CEO_Name": "Matt Maloney",
        "Company": "Grubhub",
        "Company_Ticker": "GRUB",
        "Age": 44,
        "TWTR_Handle": "m3aloney",
    },
    {
        "CEO_Name": "Chris Kempczinski",
        "Company": "McDonald's Corporation",
        "Company_Ticker": "MCS",
        "Age": 52,
        "TWTR_Handle": "null"  
    },
    {
        "CEO_Name": "Stephen Easterbrook",
        "Company": "McDonald's Corporation",
        "Company_Ticker": "MCS",
        "Age": 53,
        "TWTR_Handle": "null"  
    },
    {
        "CEO_Name": "Brian Cornell",
        "Company": "Target Corporation",
        "Company_Ticker": "TGT",
        "Age": 63,
        "TWTR_Handle": "null",
    },
    {
        "CEO_Name": "Jeff Bezos",
        "Company": "Amazon.com",
        "Company_Ticker": "AMZN",
        "Age": 57,
        "TWTR_Handle": "JeffBezos",
    },
    {
        "CEO_Name": "Doug McMillon",
        "Company": "WalMart",
        "Company_Ticker": "WMT",
        "Age": 54,
        "TWTR_Handle": "null",    
    },
    {
        "CEO_Name": "Greg Creed",
        "Company": "Yum! Brands",
        "Company_Ticker": "YUM",
        "Age": 62,
        "TWTR_Handle": "null",
    },
    {
        "CEO_Name": "David Gibbs",
        "Company": "Yum! Brands",
        "Company_Ticker": "YUM",
        "Age": 56,
        "TWTR_Handle": "null"  
    }
]

print(CEOs)
# Out:
# [{'CEO_Name': 'Elon Musk', 'Company': 'Tesla', 'Company_Ticker': 'TSLA', 'Age': 50, 'TWTR_Handle': 'elonmusk'}, {'CEO_Name': 'Jim Farley', 'Company': 'Ford Motor Company', 'Company_Ticker': 'F', 'Age': 58, 'TWTR_Handle': 'jimfarley98'}, {'CEO_Name': 'Jim Hackett', 'Company': 'Ford Motor Company', 'Company_Ticker': 'F', 'Age': 66, 'TWTR_Handle': 'null'}, {'CEO_Name': 'Mary Barra', 'Company': 'General Motors', 'Company_Ticker': 'GM', 'Age': 59, 'TWTR_Handle': 'mtbarra'}, {'CEO_Name': 'Matt Maloney', 'Company': 'Grubhub', 'Company_Ticker': 'GRUB', 'Age': 44, 'TWTR_Handle': 'm3aloney'}, {'CEO_Name': 'Chris Kempczinski', 'Company': "McDonald's Corporation", 'Company_Ticker': 'MCS', 'Age': 52, 'TWTR_Handle': 'null'}, {'CEO_Name': 'Stephen Easterbrook', 'Company': "McDonald's Corporation", 'Company_Ticker': 'MCS', 'Age': 53, 'TWTR_Handle': 'null'}, {'CEO_Name': 'Brian Cornell', 'Company': 'Target Corporation', 'Company_Ticker': 'TGT', 'Age': 63, 'TWTR_Handle': 'null'}, {'CEO_Name': 'Jeff Be
# ...
