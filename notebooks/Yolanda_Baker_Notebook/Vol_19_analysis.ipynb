# %%
import pandas as pd 
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
import matplotlib.dates as mdates
import os

# %%
os.listdir("./data")
# Out:
# ['AMZN_19.csv', 'F_19.csv', 'GM_19.csv', 'TSLA_19.csv']

# %%
stock_data = []
for file in os.listdir("./data"):
    stock_data.append(pd.read_csv(f"./data/{file}"))
stock_data[0]
# Out:
#            Date Close/Last   Volume      Open      High         Low
# 0    12/31/2019   $1847.84  2510380     $1842  $1853.26    $1832.23
# 1    12/30/2019   $1846.89  3677306     $1874     $1884    $1840.62
# 2    12/27/2019    $1869.8  6188754  $1882.92   $1901.4    $1866.01
# 3    12/26/2019   $1868.77  6024608  $1801.01  $1870.46     $1799.5
# 4    12/24/2019   $1789.21   881337  $1793.81  $1795.57   $1787.575
# ..          ...        ...      ...       ...       ...         ...
# 247  01/08/2019   $1656.58  8830753  $1664.69  $1676.61    $1616.61
# 248  01/07/2019   $1629.51  7971720  $1602.31  $1634.56   $1589.185
# 249  01/04/2019   $1575.39  9161701     $1530     $1594  $1518.3101
# 250  01/03/2019   $1500.28  6934218  $1520.01     $1538    $1497.11
# 251  01/02/2019   $1539.13  7871967   $1465.2  $1553.36    $1460.93
#
# [252 rows x 6 columns]

# %%
df = pd.read_csv(f"./data/TSLA_19.csv")
# stock_data['day']=stock_data['Date'].timetuple().tm_yday
plt.plot(df['Date'], df['Volume'])
plt.xlabel('2019')
plt.ylabel('Volume x 100M')
plt.title('TSLA')
# Out:
# Text(0.5, 1.0, 'TSLA')

# %%
def read_stock_csv(stock_file):
    df = pd.read_csv(
        f"./data/{stock_file}",
        index_col="Date",
        parse_dates=True,
        infer_datetime_format=True)
    try:
        return df["Volume"].astype("float")
    except:
        return df["Volume"]

# %%
read_stock_csv("TSLA_19.csv")
# Out:
# Date
# 2019-12-31    51462300.0
# 2019-12-30    63006350.0
# 2019-12-27    49784135.0
# 2019-12-26    53241450.0
# 2019-12-24    40273600.0
#                  ...
# 2019-01-08    34972135.0
# 2019-01-07    37711690.0
# 2019-01-04    36913775.0
# 2019-01-03    34742885.0
# 2019-01-02    58056350.0
# Name: Volume, Length: 252, dtype: float64

# %%
stock_data = []
for file in os.listdir("./data"):
    stock_data.append(read_stock_csv(file))
stock_data[0]
# Out:
# Date
# 2019-12-31    2510380.0
# 2019-12-30    3677306.0
# 2019-12-27    6188754.0
# 2019-12-26    6024608.0
# 2019-12-24     881337.0
#                 ...
# 2019-01-08    8830753.0
# 2019-01-07    7971720.0
# 2019-01-04    9161701.0
# 2019-01-03    6934218.0
# 2019-01-02    7871967.0
# Name: Volume, Length: 252, dtype: float64

# %%
all_volume = pd.DataFrame()
stock_data = []
stock_names = os.listdir("./data")
df_TSLA=pd.read_csv('./data/TSLA_19.csv')
df_F=pd.read_csv('./data/F_19.csv')
df_GM=pd.read_csv('./data/GM_19.csv')
df_AMZN=pd.read_csv('./data/AMZN_19.csv')
all_volume['Date']=df_TSLA['Date']
all_volume['TSLA']=df_TSLA['Volume']
all_volume['Date']=df_TSLA['Date']
# all_volume.join(df_F.set_index('Date'),on='Date')
# all_volume.rename(columns={"Volume":"Ford"}, inplace=True)
fig, ax=plt.subplots()
ax.plot(df_TSLA['Date'], df_TSLA['Volume'], label='TSLA')
ax.plot(df_F['Date'], df_F['Volume'], label='F')
ax.plot(df_GM['Date'], df_GM['Volume'], label='GM')
ax.plot(df_AMZN['Date'], df_AMZN['Volume'], label='AMZN')
ax.legend() 
ax.set_xlabel('2019')
ax.set_ylabel('Volume x 100M')
ax.set_title('Firms with Personal CEO TWTR Account')
# convert date to day of the year
# all_volume['Day']=all_volume['Date'].Period(freq='D').day_of_the_year
# Minor ticks every month.
fmt_month = mdates.MonthLocator()
# ax.xaxis.set_minor_locator(fmt_month)

# Text in the x axis will be displayed in 'YYYY-mm' format.
# ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

# %%
#plot each stock on the same plot
#plt.plot(df['Date'], df['AMZN_18.csv'], label='Amazon 2018')
#plt.plot(df['Date'], df['F_18.csv'], label='Ford 2018')
#plt.plot(df['Date'], df['GM_18.csv'], label='GM 2018')
#plt.plot(df['Date'], df['TSLA_18.csv'], label='Tesla 2018')
#plt.legend()
