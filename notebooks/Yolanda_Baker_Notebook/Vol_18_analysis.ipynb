# %%
import pandas as pd 
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
import matplotlib.dates as mdates
import os

# %%
os.listdir("./data")
# Out:
# ['AMZN_18.csv', 'F_18.csv', 'GM_18.csv', 'TSLA_18.csv']

# %%
stock_data = []
for file in os.listdir("./data"):
    stock_data.append(pd.read_csv(f"./data/{file}"))
stock_data[0]
# Out:
#            Date Close/Last    Volume      Open        High       Low
# 0    12/31/2018   $1501.97   6941598   $1510.8    $1520.76     $1487
# 1    12/28/2018   $1478.02   8822598  $1473.35    $1513.47     $1449
# 2    12/27/2018   $1461.64   9631228   $1454.2       $1469  $1390.31
# 3    12/26/2018    $1470.9  10332870  $1368.89  $1473.1567  $1363.01
# 4    12/24/2018   $1343.96   7219996     $1346    $1396.03     $1307
# ..          ...        ...       ...       ...         ...       ...
# 246  01/08/2018   $1246.87   4270121     $1236   $1253.079  $1232.03
# 247  01/05/2018   $1229.14   3536299  $1217.51    $1229.14     $1210
# 248  01/04/2018   $1209.59   3015997     $1205  $1215.8699  $1204.66
# 249  01/03/2018    $1204.2   3094175   $1188.3    $1205.49   $1188.3
# 250  01/02/2018   $1189.01   2673958     $1172       $1190  $1170.51
#
# [251 rows x 6 columns]

# %%
df = pd.read_csv(f"./data/TSLA_18.csv")
# stock_data['day']=stock_data['Date'].timetuple().tm_yday
plt.plot(df['Date'], df['Volume'])
plt.xlabel('2018')
plt.ylabel('Volume x 100M')
plt.title('TSLA')
# Out:
# Text(0.5, 1.0, 'TSLA')

# %%
def read_stock_csv(stock_file):
    df = pd.read_csv(
        f"./data/{stock_file}",
        index_col="Date",
        parse_dates=True,
        infer_datetime_format=True)
    try:
        return df["Volume"].astype("float")
    except:
        return df["Volume"]

# %%
read_stock_csv("TSLA_18.csv")
# Out:
# Date
# 2018-12-31    31471490.0
# 2018-12-28    49593885.0
# 2018-12-27    42836925.0
# 2018-12-26    40715510.0
# 2018-12-24    27799565.0
#                  ...
# 2018-01-08    49163050.0
# 2018-01-05    22943640.0
# 2018-01-04    49722965.0
# 2018-01-03    22192600.0
# 2018-01-02    21728075.0
# Name: Volume, Length: 251, dtype: float64

# %%
stock_data = []
for file in os.listdir("./data"):
    stock_data.append(read_stock_csv(file))
stock_data[0]
# Out:
# Date
# 2018-12-31     6941598.0
# 2018-12-28     8822598.0
# 2018-12-27     9631228.0
# 2018-12-26    10332870.0
# 2018-12-24     7219996.0
#                  ...
# 2018-01-08     4270121.0
# 2018-01-05     3536299.0
# 2018-01-04     3015997.0
# 2018-01-03     3094175.0
# 2018-01-02     2673958.0
# Name: Volume, Length: 251, dtype: float64

# %%
all_volume = pd.DataFrame()
stock_data = []
stock_names = os.listdir("./data")
df_TSLA=pd.read_csv('./data/TSLA_18.csv')
df_F=pd.read_csv('./data/F_18.csv')
df_GM=pd.read_csv('./data/GM_18.csv')
df_AMZN=pd.read_csv('./data/AMZN_18.csv')
all_volume['Date']=df_TSLA['Date']
all_volume['TSLA']=df_TSLA['Volume']
all_volume['Date']=df_TSLA['Date']
# all_volume.join(df_F.set_index('Date'),on='Date')
# all_volume.rename(columns={"Volume":"Ford"}, inplace=True)
fig, ax=plt.subplots()
ax.plot(df_TSLA['Date'], df_TSLA['Volume'], label='TSLA')
ax.plot(df_F['Date'], df_F['Volume'], label='F')
ax.plot(df_GM['Date'], df_GM['Volume'], label='GM')
ax.plot(df_AMZN['Date'], df_AMZN['Volume'], label='AMZN')
ax.legend() 
ax.set_xlabel('2018')
ax.set_ylabel('Volume x 100M')
# convert date to day of the year
# all_volume['Day']=all_volume['Date'].Period(freq='D').day_of_the_year
# Minor ticks every month.
fmt_month = mdates.MonthLocator()
# ax.xaxis.set_minor_locator(fmt_month)

# Text in the x axis will be displayed in 'YYYY-mm' format.
# ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

# %%
#plot each stock on the same plot
#plt.plot(df['Date'], df['AMZN_18.csv'], label='Amazon 2018')
#plt.plot(df['Date'], df['F_18.csv'], label='Ford 2018')
#plt.plot(df['Date'], df['GM_18.csv'], label='GM 2018')
#plt.plot(df['Date'], df['TSLA_18.csv'], label='Tesla 2018')
#plt.legend()
